# %%
import matplotlib.pyplot as plt
import numpy as np

# Training data
X_positive = np.array([[2, 3], [1, 4]])
X_negative = np.array([[3, 1], [4, 2]])

# Assumed weight and bias
w = np.array([1, -2])
b = 5

# Visualization
plt.scatter(X_positive[:, 0], X_positive[:, 1], marker='o', label='+1')
plt.scatter(X_negative[:, 0], X_negative[:, 1], marker='x', label='-1')

# Plotting the hyperplane
x1_values = np.linspace(0, 5, 100)
x2_values = (x1_values - 5) / (-2)
plt.plot(x1_values, x2_values, color='k', linestyle='-', linewidth=2, label='Hyperplane')

plt.title("Hyperplane and Training Data")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.legend()
plt.show()

# %%
# Load the important packages
from sklearn.datasets import load_breast_cancer
import matplotlib.pyplot as plt
from sklearn.inspection import DecisionBoundaryDisplay
from sklearn.svm import SVC

# Load the datasets
cancer = load_breast_cancer()
X = cancer.data[:, :2]
y = cancer.target

#Build the model
svm = SVC(kernel="rbf", gamma=0.5, C=1.0)
# Trained the model
svm.fit(X, y)

# Plot Decision Boundary
DecisionBoundaryDisplay.from_estimator(
		svm,
		X,
		response_method="predict",
		cmap=plt.cm.Spectral,
		alpha=0.8,
		xlabel=cancer.feature_names[0],
		ylabel=cancer.feature_names[1],
	)

# Scatter plot
plt.scatter(X[:, 0], X[:, 1], 
			c=y, 
			s=20, edgecolors="k")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Training data
X_positive = np.array([[2, 3], [1, 4]])
X_negative = np.array([[3, 1], [4, 2]])

# Assumed weight and bias
w = np.array([1, -2])
b = 5

# Decision function
def decision_function(x):
    return np.dot(w, x) - b

# Visualization
plt.scatter(X_positive[:, 0], X_positive[:, 1], marker='o', label='+1')
plt.scatter(X_negative[:, 0], X_negative[:, 1], marker='x', label='-1')

# Plotting the hyperplane
x1_values = np.linspace(0, 5, 100)
x2_values = (x1_values + b) / 2
plt.plot(x1_values, x2_values, color='k', linestyle='-', linewidth=2, label='Hyperplane')

# Highlighting decision regions
for i in range(4):
    point = X_positive[i] if i < 2 else X_negative[i-2]
    plt.annotate(
        f"{decision_function(point):.2f}",
        (point[0]+0.1, point[1]),
        textcoords="offset points",
        xytext=(0,5),
        ha='center'
    )

plt.title("Corrected Hyperplane and Training Data")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Training data
X_positive = np.array([[2, 3], [1, 4]])
X_negative = np.array([[3, 1], [4, 2]])

# Assumed weight and bias
w = np.array([1, -2])
b = 5

# Decision function
def decision_function(x):
    return np.dot(w, x) - b

# Visualization
plt.scatter(X_positive[:, 0], X_positive[:, 1], marker='o', label='+1')
plt.scatter(X_negative[:, 0], X_negative[:, 1], marker='x', label='-1')

# Plotting the hyperplane
x1_values = np.linspace(0, 5, 100)
x2_values = (x1_values * w[0] + b) / -w[1]
plt.plot(x1_values, x2_values, color='k', linestyle='-', linewidth=2, label='Hyperplane')

# Highlighting decision regions
for i in range(4):
    point = X_positive[i] if i < 2 else X_negative[i-2]
    plt.annotate(
        f"{decision_function(point):.2f}",
        (point[0]+0.1, point[1]),
        textcoords="offset points",
        xytext=(0,5),
        ha='center'
    )

plt.title("Corrected Hyperplane and Training Data")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Training data
X_positive = np.array([[2, 3], [1, 4]])
X_negative = np.array([[3, 1], [4, 2]])

# Assumed weight and bias
w = np.array([1, -2])
b = 5

# Decision function
def decision_function(x):
    return np.dot(w, x) - b

# Visualization
plt.scatter(X_positive[:, 0], X_positive[:, 1], marker='o', label='+1')
plt.scatter(X_negative[:, 0], X_negative[:, 1], marker='x', label='-1')

# Plotting the hyperplane
x1_values = np.linspace(0, 5, 100)
x2_values = (x1_values * w[0] + b) / -w[1]
plt.plot(x1_values, x2_values, color='k', linestyle='-', linewidth=2, label='Hyperplane')

# Highlighting decision regions
for i in range(4):
    point = X_positive[i] if i < 2 else X_negative[i-2]
    plt.annotate(
        f"{decision_function(point):.2f}",
        (point[0]+0.1, point[1]),
        textcoords="offset points",
        xytext=(0,5),
        ha='center'
    )

plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)
plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
plt.title("Corrected Hyperplane and Training Data")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.legend()
plt.show()
